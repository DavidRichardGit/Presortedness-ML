# %% [markdown]
# ## SORTS (comparisons)

# %%
import math
import random

random.seed(42)

# %% [markdown]
# ### Insertion sort

# %%
def insertion_sort(A):
    comparisons = 0
    for i in range(1, len(A)):
        key = A[i]
        j = i - 1
        comparisons += 1
        while j >= 0 and A[j] > key:
            comparisons += 1
            A[j + 1] = A[j]
            j -= 1
        A[j + 1] = key
    return comparisons

# %% [markdown]
# ### Selection sort

# %%
def selection_sort(A):
    comparisons = 0
    n = len(A)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            comparisons += 1
            if A[j] < A[min_index]:
                min_index = j
        A[i], A[min_index] = A[min_index], A[i]
    return comparisons

# %% [markdown]
# ### Merge sort

# %%
def merge_sort(A):
    if len(A) <= 1:
        return 0
    mid = len(A) // 2
    left = A[:mid]
    right = A[mid:]

    # Recursive call on each half
    comparecount = merge_sort(left) + merge_sort(right)

    # Two iterators for traversing the two halves
    i = 0
    j = 0
    
    # Iterator for the main list
    k = 0
    
    while i < len(left) and j < len(right):
        comparecount += 1
        if left[i] <= right[j]:
            # The value from the left half has been used
            A[k] = left[i]
            # Move the iterator forward
            i += 1
        else:
            A[k] = right[j]
            j += 1
        # Move to the next slot
        k += 1

    # For all the remaining values
    while i < len(left):
        comparecount += 1
        A[k] = left[i]
        i += 1
        k += 1

    while j < len(right):
        comparecount += 1
        A[k]=right[j]
        j += 1
        k += 1

    return comparecount

# %% [markdown]
# ### Heap sort

# %%
def heapify(A, n, i, comparisons):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2

    if l < n and A[l] > A[largest]:
        largest = l
        comparisons[0] += 1

    if r < n and A[r] > A[largest]:
        largest = r
        comparisons[0] += 1

    if largest != i:
        A[i], A[largest] = A[largest], A[i]
        heapify(A, n, largest, comparisons)

def heap_sort(A):
    comparisons = [0]
    n = len(A)

    for i in range(n // 2 - 1, -1, -1):
        heapify(A, n, i, comparisons)

    for i in range(n - 1, 0, -1):
        A[i], A[0] = A[0], A[i]
        heapify(A, i, 0, comparisons)

    return comparisons[0]

# %% [markdown]
# ### Quick sort

# %%
def quicksort(A):
    comparisons = [0]
    quickSorter(A, 0, len(A) - 1, comparisons)
    return comparisons[0]

def partition(A, low, high, comparisons):
    pivot = A[high]
    i = low - 1
    for j in range(low, high):
        comparisons[0] += 1
        if A[j] <= pivot:
            i += 1
            A[i], A[j] = A[j], A[i]
    A[i + 1], A[high] = A[high], A[i + 1]
    return i + 1

def quickSorter(A, low, high, comparisons):
    if low < high:
        pi = partition(A, low, high, comparisons)
        quickSorter(A, low, pi - 1, comparisons)
        quickSorter(A, pi + 1, high, comparisons)

# %% [markdown]
# ### Timsort

# %%
MINIMUM = 32

def find_minrun(n): 
    r = 0
    while n >= MINIMUM: 
        r |= n & 1
        n >>= 1
    return n + r 

def tim_insertion_sort(array, left, right): 
    global comparisons
    for i in range(left + 1, right + 1):
        key = array[i]
        j = i - 1
        comparisons += 1
        while j >= left and key < array[j]:
            array[j + 1] = array[j]
            j -= 1
            comparisons += 1
        array[j + 1] = key
    return array
              
def tim_merge(array, l, m, r): 
    global comparisons
    array_length1 = m - l + 1
    array_length2 = r - m 
    left = []
    right = []
    for i in range(array_length1): 
        left.append(array[l + i]) 
    for i in range(array_length2): 
        right.append(array[m + 1 + i]) 
  
    i = 0
    j = 0
    k = l
   
    while j < array_length2 and i < array_length1: 
        if left[i] <= right[j]: 
            array[k] = left[i] 
            i += 1
        else: 
            array[k] = right[j] 
            j += 1
        k += 1
        comparisons += 1
  
    while i < array_length1: 
        array[k] = left[i] 
        k += 1
        i += 1
        comparisons += 1
  
    while j < array_length2: 
        array[k] = right[j] 
        k += 1
        j += 1
        comparisons += 1
  
def timsort(array): 
    n = len(array) 
    minrun = find_minrun(n) 
  
    for start in range(0, n, minrun): 
        end = min(start + minrun - 1, n - 1) 
        tim_insertion_sort(array, start, end) 
   
    size = minrun 
    while size < n: 
        for left in range(0, n, 2 * size): 
            mid = min(n - 1, left + size - 1) 
            right = min((left + 2 * size - 1), (n - 1)) 
            tim_merge(array, left, mid, right) 
        size = 2 * size

    return comparisons

# %% [markdown]
# ### Introsort

# %%
def introsort(arr):

    def partition(arr, low, high):
        pivot = arr[high]
        i = low - 1
        for j in range(low, high):
            comparisons[0] += 1
            if arr[j] <= pivot:
                i += 1
                arr[i], arr[j] = arr[j], arr[i]
        arr[i + 1], arr[high] = arr[high], arr[i + 1]
        return i + 1

    def insertion_sort(arr, low, high):
        for i in range(low + 1, high + 1):
            key = arr[i]
            j = i - 1
            comparisons[0] += 1
            while j >= low and arr[j] > key:
                comparisons[0] += 1
                arr[j + 1] = arr[j]
                j -= 1
            arr[j + 1] = key

    def heap_sort(arr):
        def heapify(arr, n, i):
            largest = i
            l = 2 * i + 1
            r = 2 * i + 2

            if l < n and arr[i] < arr[l]:
                largest = l

            if r < n and arr[largest] < arr[r]:
                largest = r

            if largest != i:
                arr[i], arr[largest] = arr[largest], arr[i]
                heapify(arr, n, largest)

        n = len(arr)

        for i in range(n // 2 - 1, -1, -1):
            heapify(arr, n, i)

        for i in range(n - 1, 0, -1):
            arr[i], arr[0] = arr[0], arr[i]
            heapify(arr, i, 0)

    def introsort_util(arr, low, high, depth_limit):
        size = high - low + 1

        if size < 16:
            insertion_sort(arr, low, high)
            return

        if depth_limit == 0:
            heap_sort(arr)
            return

        pivot = partition(arr, low, high)

        introsort_util(arr, low, pivot - 1, depth_limit - 1)
        introsort_util(arr, pivot + 1, high, depth_limit - 1)

    comparisons = [0]
    introsort_util(arr, 0, len(arr) - 1, 2 * math.log(len(arr)))
    return comparisons[0]

# %% [markdown]
# ## PRESORTEDNESS

# %% [markdown]
# ### Number of Runs
# The number of runs, is the number of increasing sequences in an array minus one.

# %%
def runs(arr):
    count = 0

    for key in range(1,len(arr)):
        if arr[key] < arr[key-1]:
            count += 1

    return count

arr = [3, 4, 4, 7]
print(runs(arr))
# Out:
# 0

# %% [markdown]
# ### Number of Deletions
# minimum number of elements that need to be removed from array to obtain a sorted sequence.

# %%
def deletions(arr):
    def ceil_index(sub, val):
        l, r = 0, len(sub)-1
        while l <= r:
            mid = (l + r) // 2
            if sub[mid] >= val:
                r = mid - 1
            else:
                l = mid + 1
        return l
 
    sub = [arr[0]]
    for i in range(1, len(arr)):
        if arr[i] >= sub[-1]:
            sub.append(arr[i])
        else:
            sub[ceil_index(sub, arr[i])] = arr[i]
 
    return len(arr) - len(sub)

arr = [3, 4, 5, 7]
print(deletions(arr))
# Out:
# 0

# %% [markdown]
# ### Number of Inversions
# The number of inversion in an array, is the number of pairs j < key such that arr[j] > key.

# %%
def inversions(arr):
    count = 0

    for key in range(len(arr)):
        for j in range(key):
            if arr[key] < arr[j]:
                count += 1

    return count

arr = [3, 4, 4, 7]
print(inversions(arr))
# Out:
# 0

# %% [markdown]
# ## Setup and Datasets import/cleaning

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

os.getcwd()

dataset_directory = './kaggledatasets'
dataset_dfs = {}

# import files in the directory
for file_name in os.listdir(dataset_directory):
    try:
        dataset_name = os.path.splitext(file_name)[0]
        dataset_dfs[dataset_name] = pd.read_csv(os.path.join(dataset_directory, file_name))
    except pd.errors.ParserError as e:
        print(f"Error reading file '{file_name}': {e}")
        continue

print("amount of dataframes imported:")
print(len(dataset_dfs))

ARRAY_SIZE = 200

for key, df in dataset_dfs.items():
    for column in df.columns:
        if not df[column].apply(lambda x: isinstance(x, (int, float))).all() or len(df[column].values) < ARRAY_SIZE:
            df.drop(column, axis=1, inplace=True)
            
    dataset_dfs[key] = df.dropna().head(ARRAY_SIZE)
# Out:
# Error reading file 'chord-fingers.csv': Error tokenizing data. C error: Expected 10 fields in line 7, saw 11
#
# amount of dataframes imported:
# 51

# %% [markdown]
# ## Sorting and training set creation

# %%
results = []

for key, df in dataset_dfs.items():
    for column in df.columns:
        arr = df[column].values
        if len(arr) == 0:
            continue
        #sample_size = math.floor(math.sqrt(len(arr)))*2
        sample_size = 10

        indices = np.random.choice(len(arr), size=sample_size, replace=False)
        indices.sort()
        arr_random = arr[indices]
        
        sample_size3 = math.floor(sample_size/3)
        middle = len(arr)//2
        arr1 = arr[:sample_size3]
        arr2 = arr[middle - sample_size3//2:middle+sample_size3//2]
        arr3 = arr[-sample_size3-1:-1]
        arr_mixed = np.concatenate((arr1,arr2,arr3))

        step = len(arr) // sample_size
        arr_dist = [arr[i] for i in range(0, len(arr), step)]

        
        runs_val_random = runs(arr_random)
        inversions_val_random = inversions(arr_random)
        deletions_val_random = deletions(arr_random)
        
        runs_val_mixed = runs(arr_mixed)
        inversions_val_mixed = inversions(arr_mixed)
        deletions_val_mixed = deletions(arr_mixed)
        
        runs_val_dist = runs(arr_dist)
        inversions_val_dist = inversions(arr_dist)
        deletions_val_dist = deletions(arr_dist)

        runs_val = runs(arr)
        inversions_val = inversions(arr)
        deletions_val = deletions(arr)

        comp_merge = merge_sort(arr.copy())
        comp_selection = selection_sort(arr.copy())
        comp_quick = quicksort(arr.copy())
        comp_intro = introsort(arr.copy())
        comp_insertion = insertion_sort(arr.copy())
        global comparisons
        comparisons = 0
        comp_tim = timsort(arr.copy())
        comparisons = 0
        comp_heap = heap_sort(arr.copy())
        
        comparison_counts = {
            'introsort': comp_intro,
            'insertion_sort': comp_insertion,
            'merge_sort': comp_merge,
            'timsort': comp_tim,
            'quick_sort': comp_quick,
            'selection_sort': comp_selection,
            #'heap_sort': comp_heap, this is bugged (sometimes outputs 0)
        }

        min_algorithm = min(comparison_counts, key=comparison_counts.get)
        min_comparisons = comparison_counts[min_algorithm]

        results.append({
            'Dataset': key,
            'Column': column,
            'Algorithm': min_algorithm,
            'Comparisons': min_comparisons,
            'Runs': runs_val,
            'Inversions': inversions_val,
            'Deletions': deletions_val,

            'Runs_random': runs_val_random,
            'Inversions_random': inversions_val_random,
            'Deletions_random': deletions_val_random,

            'Runs_mixed': runs_val_mixed,
            'Inversions_mixed': inversions_val_mixed,
            'Deletions_mixed': deletions_val_mixed,

            'Runs_dist': runs_val_dist,
            'Inversions_dist': inversions_val_dist,
            'Deletions_dist': deletions_val_dist,

            'introsort': comp_intro,
            'insertion_sort': comp_insertion,
            'merge_sort': comp_merge,
            'timsort': comp_tim,
            'heap_sort': comp_heap,
            'quick_sort': comp_quick,
            'selection_sort': comp_selection,

        })

df_results = pd.DataFrame(results)
print(df_results)
# Out:
#                       Dataset            Column       Algorithm  Comparisons  \
# 0               538ratingsMen            Season  insertion_sort          199
# 1               538ratingsMen            TeamID      quick_sort         1318
# 2               538ratingsMen         538rating      merge_sort         1544
# 3             538ratingsWomen            Season  insertion_sort          199
# 4             538ratingsWomen            TeamID      quick_sort         1505
# ..                        ...               ...             ...          ...
# 195                 wines_SPA           acidity         timsort          960
# 196                  Youtuber              Rank  insertion_sort          199
# 197  yt_sports_channels_stats       video_count      merge_sort         1544
# 198  yt_sports_channels_stats        view_count      merge_sort         1544
# 199  yt_sports_channels_stats  subscriber_count      merge_sort         1544
#
#      Runs  Inversions  Deletions  Runs_random  Inversions_random  \
# 0       0           0          0            0                  0
# 1      94       10190        175            4                 19
# 2     133       12764        189            6                 30
# 3       0           0          0            0                  0
# 4      97       10341        179            7                 38
# ..    ...         ...        ...          ...                ...
# 195    14        1465         15            0                  0
# 196     0           0          0            0                  0
# 197    94       12032        178            6                 32
# 198   104       12988        177            6                 30
# 199   104       12768        179            5                 29
#
#      Deletions_random  ...  Runs_dist  Inversions_dist  Deletions_dist  \
# 0                   0  ...          0                0               0
# 1                   5  ...          4               31               7
# 2                   7  ...          7               26               7
# 3                   0  ...          0                0               0
# 4                   7  ...          4               20               5
# ..                ...  ...        ...              ...             ...
# 195                 0  ...          0                0               0
# 196                 0  ...          0                0               0
# 197                 6  ...          4               30               6
# 198                 6  ...          5               33               7
# 199                 7  ...          5               34               7
#
#      introsort  insertion_sort  merge_sort  timsort  heap_sort  quick_sort  \
# 0        19809             199        1544      792        913       19900
# 1         1421           10389        1544     1990       1615        1318
# 2         2193           12963        1544     2747       1535        2034
# 3        19809             199        1544      792        972       19900
# 4         1608           10540        1544     1926       1635        1505
# ..         ...             ...         ...      ...        ...         ...
# 195      17321            1664        1544      960        278       17464
# 196      19809             199        1544      792       1895       19900
# 197       1686           12231        1544     2109       1615        1550
# 198       1838           13187        1544     2189       1575        1734
# 199       1893           12967        1544     2180       1585        1802
#
#      selection_sort
# 0             19900
# 1             19900
# 2             19900
# 3             19900
# 4             19900
# ..              ...
# 195           19900
# 196           19900
# 197           19900
# 198           19900
# 199           19900
#
# [200 rows x 23 columns]

# %% [markdown]
# ## Neural network model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
tf.random.set_seed(42)

X = df_results[['Runs_dist',  'Inversions_dist', 'Deletions_dist']]
y = df_results['Algorithm']

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.3341
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3319
# Epoch 355/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.3310
# Epoch 356/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3307
# Epoch 357/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3315
# Epoch 358/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8406 - loss: 0.3311
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.3293
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8496 - loss: 0.3273
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.3276
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3283
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8465 - loss: 0.3262
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.3269
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3276
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8477 - loss: 0.3252
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8457 - loss: 0.3247
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3252
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.3242
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8496 - loss: 0.3223
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.3220
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3255
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3235
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8426 - loss: 0.3225
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8547 - loss: 0.3242
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8465 - loss: 0.3217
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8355 - loss: 0.3243
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8586 - loss: 0.3190
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8477 - loss: 0.3233
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3253
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8496 - loss: 0.3167
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.3165
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3119
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3145
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8547 - loss: 0.3149
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3099
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8598 - loss: 0.3095
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.3073
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3075
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3066
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3059
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8598 - loss: 0.3054
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.3045
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3048
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3046
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3048
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3017
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.3010
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3039
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3017
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.3026
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3023
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8508 - loss: 0.3012
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3084
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8637 - loss: 0.3021
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.3013
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.3043
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.3024
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.3070
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2954
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.2972
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.2984
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.2961
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2971
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2906
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.2909
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2925
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8687 - loss: 0.2902
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.2907
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.2911
# Epoch 421/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2885
# Epoch 422/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8687 - loss: 0.2896
# Epoch 423/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2876
# Epoch 424/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.2882
# Epoch 425/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2895
# Epoch 426/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2861
# Epoch 427/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.2873
# Epoch 428/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2857
# Epoch 429/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.2856
# Epoch 430/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2900
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8687 - loss: 0.2853
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8508 - loss: 0.2852
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.2855
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2834
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2875
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.2827
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.2838
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2863
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.2818
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8598 - loss: 0.2868
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8687 - loss: 0.2811
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8598 - loss: 0.2820
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2861
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2812
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2834
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2786
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2800
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2838
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2768
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2795
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2763
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.2769
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2800
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2745
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2759
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2749
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2740
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2772
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2733
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2740
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2773
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2733
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2773
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2725
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.2728
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2763
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2710
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8598 - loss: 0.2726
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2717
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2706
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2741
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.2674
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2692
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8687 - loss: 0.2702
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2670
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2719
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2657
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.2678
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2669
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2658
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2681
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2648
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2652
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2666
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2641
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2676
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2639
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2648
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2661
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2634
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2666
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2644
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2639
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.2690
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2625
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2650
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2664
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.2639
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.2702
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.2604

# %% [markdown]
# ## Results

# %%
# Make predictions on the test data and compare them to the True best Algorithm
y_pred = model.predict(X_test_scaled)
y_pred_classes = np.argmax(y_pred, axis=1)
predicted_algorithms = label_encoder.inverse_transform(y_pred_classes)
true_algorithms = label_encoder.inverse_transform(y_test)

comparison_df = pd.DataFrame({'Predicted Algorithm': predicted_algorithms, 'True Algorithm': true_algorithms})
print(comparison_df)

accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)[1]
print("Accuracy:", accuracy)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#    Predicted Algorithm  True Algorithm
# 0           quick_sort      merge_sort
# 1           merge_sort      merge_sort
# 2            introsort      quick_sort
# 3           merge_sort      merge_sort
# 4       insertion_sort         timsort
# 5           merge_sort      merge_sort
# 6           merge_sort      merge_sort
# 7           merge_sort      merge_sort
# 8              timsort         timsort
# 9            introsort      merge_sort
# 10             timsort         timsort
# 11          merge_sort       introsort
# 12             timsort      merge_sort
# 13          merge_sort      merge_sort
# 14      insertion_sort  insertion_sort
# 15      insertion_sort  insertion_sort
# 16          merge_sort         timsort
# 17          merge_sort      merge_sort
# 18      insertion_sort  insertion_sort
# 19             timsort         timsort
# 20          merge_sort      merge_sort
# 21          merge_sort       introsort
# 22          merge_sort      merge_sort
# 23          quick_sort      merge_sort
# 24             timsort         timsort
# 25          merge_sort      merge_sort
# 26      insertion_sort  insertion_sort
# 27           introsort      merge_sort
# 28             timsort         timsort
# 29      insertion_sort  insertion_sort
# 30          quick_sort      quick_sort
# 31          quick_sort       introsort
# 32             timsort         timsort
# 33          merge_sort      merge_sort
# 34             timsort         timsort
# 35          quick_sort      merge_sort
# 36          merge_sort      merge_sort
# 37          merge_sort      merge_sort
# 38          merge_sort      merge_sort
# 39          merge_sort      merge_sort
# Accuracy: 0.699999988079071

# %% [markdown]
# ### Average Comparisons

# %%
test_set_df = df_results.iloc[test_indices]
test_set_df.reset_index(drop=True, inplace=True)

c = []
t = []

for index, row in test_set_df.iterrows():
    c.append(row[predicted_algorithms[index]])
    t.append(row[true_algorithms[index]])

def calculate_average(column_name):
    return round(np.sum(test_set_df[column_name]) / len(test_set_df), 1)

minimum_possible = round(np.sum(t)/len(test_set_df), 1)
algorithm_prediction_model = round(np.sum(c)/len(test_set_df), 1)
merge_sort_avg = calculate_average('merge_sort')
timsort_avg = calculate_average('timsort')
introsort_avg = calculate_average('introsort')
quick_sort_avg = calculate_average('quick_sort')
insertion_sort_avg = calculate_average('insertion_sort')
selection_sort_avg = calculate_average('selection_sort')

data = {
    'Algorithm': ['Minimum possible', 'Algorithm Prediction Model', 'merge_sort', 'timsort', 'introsort', 'quick_sort', 'insertion_sort'],
    'Average Value': [minimum_possible, algorithm_prediction_model, merge_sort_avg, timsort_avg, introsort_avg, quick_sort_avg, insertion_sort_avg]
}
df_average_comp = pd.DataFrame(data)

# Plot
plt.figure(figsize=(8, 5))
plt.bar(df_average_comp['Algorithm'], df_average_comp['Average Value'], color='skyblue')
plt.title('Average Comparisons of Sorting Algorithms')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

print('min possible: ', minimum_possible)
print('algorithm predicting model: ', algorithm_prediction_model)
print('merge_sort: ', merge_sort_avg)
print('timsort: ', timsort_avg)
print('introsort: ', introsort_avg)
print('quick_sort: ', quick_sort_avg)
print('insertion_sort: ', insertion_sort_avg)
print('selection_sort: ', selection_sort_avg)
# Out:
# min possible:  1292.9
# algorithm predicting model:  1410.2
# merge_sort:  1544.0
# timsort:  1608.3
# introsort:  6979.9
# quick_sort:  7137.8
# insertion_sort:  7069.4
# selection_sort:  19900.0

# %% [markdown]
# ### Model analysis

# %%
from itertools import product

# Generate arrays with combinations of values
def generate_arrays(values, n):
    return [list(comb) for comb in product(values, repeat=n)]

possible_values = [100, 25, 10, 5, 0]
X_analysis = generate_arrays(possible_values, 3)

X_analysis_scaled = scaler.fit_transform(X_analysis)

y_preds = model.predict(X_analysis_scaled)
y_preds_classes = np.argmax(y_preds, axis=1)
predicted_algorithm = label_encoder.inverse_transform(y_preds_classes)

print(predicted_algorithm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ['introsort' 'quick_sort' 'quick_sort' 'quick_sort' 'quick_sort'
#  'merge_sort' 'introsort' 'introsort' 'introsort' 'timsort' 'merge_sort'
#  'introsort' 'introsort' 'introsort' 'timsort' 'merge_sort' 'introsort'
#  'introsort' 'introsort' 'timsort' 'merge_sort' 'introsort' 'introsort'
#  'introsort' 'timsort' 'timsort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'quick_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort' 'timsort' 'timsort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'timsort' 'timsort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'timsort' 'timsort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort' 'timsort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'timsort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'timsort' 'timsort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'timsort' 'timsort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'timsort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'timsort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'merge_sort' 'timsort' 'timsort' 'merge_sort' 'merge_sort' 'merge_sort'
#  'timsort' 'timsort' 'merge_sort' 'merge_sort' 'merge_sort' 'timsort'
#  'timsort' 'merge_sort' 'merge_sort' 'merge_sort' 'timsort' 'timsort'
#  'merge_sort' 'merge_sort' 'merge_sort']
